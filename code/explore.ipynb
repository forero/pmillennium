# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = '/global/cscratch1/sd/forero/density_pmillennium/field_271/density_271.8.hdf5'
f = h5py.File(filename, 'r')
print(f.keys())
data = f['Density/grid'][...]
f.close()
# Out:
# <KeysViewHDF5 ['Density']>

# %%
print(np.shape(data))
# Out:
# (16, 4096, 4096)

# %%
s = np.sum(data, axis=0)

# %%
plt.imshow(np.log10(s[:512,:512]))
# Out:
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(1-np.exp(-np.log10(s[120,:])))
plt.plot(1-np.exp(-np.log10(s[530,:])))
